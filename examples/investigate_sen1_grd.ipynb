# %%
import xarray as xr

# %%
path = (
    "s3://e05ab01a9d56408d82ac32d69a5aae2a:sample-data/tutorial_data/"
    "cpm_v253/S1A_IW_GRDH_1SDV_20240201T164915_20240201T164940_052368_065517_750E.zarr"
)

# %%
dt = xr.open_datatree(path, engine="eopf-zarr", op_mode="native", chunks={})
dt
# Out:
# <xarray.DataTree>
# Group: /
# │   Attributes: (2)
# ├── Group: /S01SIWGRD_20240201T164915_0025_A299_750E_065517_VH
# │   │   Attributes: (2)
# │   ├── Group: /S01SIWGRD_20240201T164915_0025_A299_750E_065517_VH/conditions
# │   │   ├── Group: /S01SIWGRD_20240201T164915_0025_A299_750E_065517_VH/conditions/antenna_pattern
# │   │   │       Dimensions:           (azimuth_time: 27, slant_range_time: 720)
# │   │   │       Coordinates:
# │   │   │           slant_range_time  (azimuth_time, slant_range_time) float32 78kB dask.array<chunksize=(27, 720), meta=np.ndarray>
# │   │   │         * azimuth_time      (azimuth_time) datetime64[ns] 216B 2024-02-01T16:49:15....
# │   │   │       Data variables:
# │   │   │           elevation_angle   (azimuth_time, slant_range_time) float32 78kB dask.array<chunksize=(27, 720), meta=np.ndarray>
# │   │   │           incidence_angle   (azimuth_time, slant_range_time) float32 78kB dask.array<chunksize=(27, 720), meta=np.ndarray>
# │   │   │           roll              (azimuth_time) float32 108B dask.array<chunksize=(27,), meta=np.ndarray>
# │   │   │           terrain_height    (azimuth_time) float32 108B dask.array<chunksize=(27,), meta=np.ndarray>
# │   │   ├── Group: /S01SIWGRD_20240201T164915_0025_A299_750E_065517_VH/conditions/attitude
# │   │   │       Dimensions:       (azimuth_time: 25)
# │   │   │       Coordinates:
# │   │   │         * azimuth_time  (azimuth_time) datetime64[ns] 200B 2024-02-01T16:49:15.8750...
# │   │   │       Data variables:
# │   │   │           pitch         (azimuth_time) float32 100B dask.array<chunksize=(25,), meta=np.ndarray>
# │   │   │           q0            (azimuth_time) float32 100B dask.array<chunksize=(25,), meta=np.ndarray>
# │   │   │           q1            (azimuth_time) float32 100B dask.array<chunksize=(25,), meta=np.ndarray>
# │   │   │           q2            (azimuth_time) float32 100B dask.array<chunksize=(25,), meta=np.ndarray>
# │   │   │           q3            (azimuth_time) float32 100B dask.array<chunksize=(25,), meta=np.ndarray>
# │   │   │           roll          (azimuth_time) float32 100B dask.array<chunksize=(25,), meta=np.ndarray>
# │   │   │           wx            (azimuth_time) float32 100B dask.array<chunksize=(25,), meta=np.ndarray>
# │   │   │           wy            (azimuth_time) float32 100B dask.array<chunksize=(25,), meta=np.ndarray>
# │   │   │           wz            (azimuth_time) float32 100B dask.array<chunksize=(25,), meta=np.ndarray>
# │   │   │           yaw           (azimuth_time) float32 100B dask.array<chunksize=(25,), meta=np.ndarray>
# │   │   ├── Group: /S01SIWGRD_20240201T164915_0025_A299_750E_065517_VH/conditions/azimuth_fm_rate
# │   │   │       Dimensions:                     (azimuth_time: 10, degree: 3)
# │   │   │       Coordinates:
# │   │   │         * azimuth_time                (azimuth_time) datetime64[ns] 80B 2024-02-01T...
# │   │   │       Dimensions without coordinates: degree
# │   │   │       Data variables:
# │   │   │           azimuth_fm_rate_polynomial  (azimuth_time, degree) float32 120B dask.array<chunksize=(10, 3), meta=np.ndarray>
# │   │   │           t0                          (azimuth_time) float32 40B dask.array<chunksize=(10,), meta=np.ndarray>
# │   │   ...
# │   │   ├── Group: /S01SIWGRD_20240201T164915_0025_A299_750E_065517_VH/conditions/reference_replica
# │   │   │       Dimensions:                                   (azimuth_time: 3, degree: 4)
# │   │   │       Coordinates:
# │   │   │         * azimuth_time                              (azimuth_time) datetime64[ns] 24B ...
# │   │   │       Dimensions without coordinates: degree
# │   │   │       Data variables:
# │   │   │           reference_replica_amplitude_coefficients  (azimuth_time, degree) float32 48B dask.array<chunksize=(3, 4), meta=np.ndarray>
# │   │   │           reference_replica_phase_coefficients      (azimuth_time, degree) float32 48B dask.array<chunksize=(3, 4), meta=np.ndarray>
# │   │   ├── Group: /S01SIWGRD_20240201T164915_0025_A299_750E_065517_VH/conditions/replica
# │   │   │       Dimensions:                           (azimuth_time: 15)
# │   │   │       Coordinates:
# │   │   │         * azimuth_time                      (azimuth_time) datetime64[ns] 120B 2024...
# │   │   │       Data variables:
# │   │   │           absolute_pg_product_valid_flag    (azimuth_time) bool 15B dask.array<chunksize=(15,), meta=np.ndarray>
# │   │   │           cross_correlation_peak_location   (azimuth_time) float32 60B dask.array<chunksize=(15,), meta=np.ndarray>
# │   │   │           cross_correlation_pslr            (azimuth_time) float32 60B dask.array<chunksize=(15,), meta=np.ndarray>
# │   │   │           internal_time_delay               (azimuth_time) float32 60B dask.array<chunksize=(15,), meta=np.ndarray>
# │   │   │           model_pg_product_amplitude        (azimuth_time) float32 60B dask.array<chunksize=(15,), meta=np.ndarray>
# │   │   │           model_pg_product_phase            (azimuth_time) float32 60B dask.array<chunksize=(15,), meta=np.ndarray>
# │   │   │           pg_product_amplitude              (azimuth_time) float32 60B dask.array<chunksize=(15,), meta=np.ndarray>
# │   │   │           pg_product_phase                  (azimuth_time) float32 60B dask.array<chunksize=(15,), meta=np.ndarray>
# │   │   │           reconstructed_replica_valid_flag  (azimuth_time) bool 15B dask.array<chunksize=(15,), meta=np.ndarray>
# │   │   │           relative_pg_product_valid_flag    (azimuth_time) bool 15B dask.array<chunksize=(15,), meta=np.ndarray>
# │   │   └── Group: /S01SIWGRD_20240201T164915_0025_A299_750E_065517_VH/conditions/terrain_height
# │   │           Dimensions:         (azimuth_time: 5)
# │   │           Coordinates:
# │   │             * azimuth_time    (azimuth_time) datetime64[ns] 40B 2024-02-01T16:49:05.722...
# │   │           Data variables:
# │   │               terrain_height  (azimuth_time) float32 20B dask.array<chunksize=(5,), meta=np.ndarray>
# │   ├── Group: /S01SIWGRD_20240201T164915_0025_A299_750E_065517_VH/measurements
# │   │       Dimensions:       (azimuth_time: 16675, ground_range: 26456)
# │   │       Coordinates:
# │   │         * azimuth_time  (azimuth_time) datetime64[ns] 133kB 2024-02-01T16:49:15.722...
# │   │       Dimensions without coordinates: ground_range
# │   │       Data variables:
# │   │           grd           (azimuth_time, ground_range) uint16 882MB dask.array<chunksize=(2536, 26456), meta=np.ndarray>
# │   └── Group: /S01SIWGRD_20240201T164915_0025_A299_750E_065517_VH/quality
# │       ├── Group: /S01SIWGRD_20240201T164915_0025_A299_750E_065517_VH/quality/calibration
# │       │       Dimensions:       (azimuth_time: 27, ground_range: 663)
# │       │       Coordinates:
# │       │         * azimuth_time  (azimuth_time) datetime64[ns] 216B 2024-02-01T16:49:15.7228...
# │       │         * ground_range  (ground_range) float32 3kB 0.0 6.67e+06 ... 4.411e+09
# │       │           line          (azimuth_time) int32 108B dask.array<chunksize=(27,), meta=np.ndarray>
# │       │           pixel         (ground_range) int32 3kB dask.array<chunksize=(663,), meta=np.ndarray>
# │       │       Data variables:
# │       │           beta_nought   (azimuth_time, ground_range) float32 72kB dask.array<chunksize=(27, 663), meta=np.ndarray>
# │       │           dn            (azimuth_time, ground_range) float32 72kB dask.array<chunksize=(27, 663), meta=np.ndarray>
# │       │           gamma         (azimuth_time, ground_range) float32 72kB dask.array<chunksize=(27, 663), meta=np.ndarray>
# │       │           sigma_nought  (azimuth_time, ground_range) float32 72kB dask.array<chunksize=(27, 663), meta=np.ndarray>
# │       └── Group: /S01SIWGRD_20240201T164915_0025_A299_750E_065517_VH/quality/noise
# │               Dimensions:                        (azimuth_time: 797)
# │               Coordinates:
# │                 * azimuth_time                   (azimuth_time) datetime64[ns] 6kB 2024-02-...
# │               Data variables:
# │                   noise_power_correction_factor  (azimuth_time) float32 3kB dask.array<chunksize=(797,), meta=np.ndarray>
# │                   number_of_noise_lines          (azimuth_time) int32 3kB dask.array<chunksize=(797,), meta=np.ndarray>
# └── Group: /S01SIWGRD_20240201T164915_0025_A299_750E_065517_VV
#     │   Attributes: (2)
#     ├── Group: /S01SIWGRD_20240201T164915_0025_A299_750E_065517_VV/conditions
#     │   ├── Group: /S01SIWGRD_20240201T164915_0025_A299_750E_065517_VV/conditions/antenna_pattern
#     │   │       Dimensions:           (azimuth_time: 27, slant_range_time: 720)
#     │   │       Coordinates:
#     │   │           slant_range_time  (azimuth_time, slant_range_time) float32 78kB dask.array<chunksize=(27, 720), meta=np.ndarray>
#     │   │         * azimuth_time      (azimuth_time) datetime64[ns] 216B 2024-02-01T16:49:15....
#     │   │       Data variables:
#     │   │           elevation_angle   (azimuth_time, slant_range_time) float32 78kB dask.array<chunksize=(27, 720), meta=np.ndarray>
#     │   │           incidence_angle   (azimuth_time, slant_range_time) float32 78kB dask.array<chunksize=(27, 720), meta=np.ndarray>
#     │   │           roll              (azimuth_time) float32 108B dask.array<chunksize=(27,), meta=np.ndarray>
#     │   │           terrain_height    (azimuth_time) float32 108B dask.array<chunksize=(27,), meta=np.ndarray>
#     │   ├── Group: /S01SIWGRD_20240201T164915_0025_A299_750E_065517_VV/conditions/attitude
#     │   │       Dimensions:       (azimuth_time: 25)
#     │   │       Coordinates:
#     │   │         * azimuth_time  (azimuth_time) datetime64[ns] 200B 2024-02-01T16:49:15.8750...
#     │   │       Data variables:
#     │   │           pitch         (azimuth_time) float32 100B dask.array<chunksize=(25,), meta=np.ndarray>
#     │   │           q0            (azimuth_time) float32 100B dask.array<chunksize=(25,), meta=np.ndarray>
#     │   │           q1            (azimuth_time) float32 100B dask.array<chunksize=(25,), meta=np.ndarray>
#     │   │           q2            (azimuth_time) float32 100B dask.array<chunksize=(25,), meta=np.ndarray>
#     │   │           q3            (azimuth_time) float32 100B dask.array<chunksize=(25,), meta=np.ndarray>
#     │   │           roll          (azimuth_time) float32 100B dask.array<chunksize=(25,), meta=np.ndarray>
#     │   │           wx            (azimuth_time) float32 100B dask.array<chunksize=(25,), meta=np.ndarray>
#     │   │           wy            (azimuth_time) float32 100B dask.array<chunksize=(25,), meta=np.ndarray>
#     │   │           wz            (azimuth_time) float32 100B dask.array<chunksize=(25,), meta=np.ndarray>
#     │   │           yaw           (azimuth_time) float32 100B dask.array<chunksize=(25,), meta=np.ndarray>
#     │   ├── Group: /S01SIWGRD_20240201T164915_0025_A299_750E_065517_VV/conditions/azimuth_fm_rate
#     │   │       Dimensions:                     (azimuth_time: 10, degree: 3)
#     │   │       Coordinates:
#     │   │         * azimuth_time                (azimuth_time) datetime64[ns] 80B 2024-02-01T...
#     │   │       Dimensions without coordinates: degree
#     │   │       Data variables:
#     │   │           azimuth_fm_rate_polynomial  (azimuth_time, degree) float32 120B dask.array<chunksize=(10, 3), meta=np.ndarray>
#     │   │           t0                          (azimuth_time) float32 40B dask.array<chunksize=(10,), meta=np.ndarray>
#     │   ...
#     │   ├── Group: /S01SIWGRD_20240201T164915_0025_A299_750E_065517_VV/conditions/reference_replica
#     │   │       Dimensions:                                   (azimuth_time: 3, degree: 4)
#     │   │       Coordinates:
#     │   │         * azimuth_time                              (azimuth_time) datetime64[ns] 24B ...
#     │   │       Dimensions without coordinates: degree
#     │   │       Data variables:
#     │   │           reference_replica_amplitude_coefficients  (azimuth_time, degree) float32 48B dask.array<chunksize=(3, 4), meta=np.ndarray>
#     │   │           reference_replica_phase_coefficients      (azimuth_time, degree) float32 48B dask.array<chunksize=(3, 4), meta=np.ndarray>
#     │   ├── Group: /S01SIWGRD_20240201T164915_0025_A299_750E_065517_VV/conditions/replica
#     │   │       Dimensions:                           (azimuth_time: 15)
#     │   │       Coordinates:
#     │   │         * azimuth_time                      (azimuth_time) datetime64[ns] 120B 2024...
#     │   │       Data variables:
#     │   │           absolute_pg_product_valid_flag    (azimuth_time) bool 15B dask.array<chunksize=(15,), meta=np.ndarray>
#     │   │           cross_correlation_peak_location   (azimuth_time) float32 60B dask.array<chunksize=(15,), meta=np.ndarray>
#     │   │           cross_correlation_pslr            (azimuth_time) float32 60B dask.array<chunksize=(15,), meta=np.ndarray>
#     │   │           internal_time_delay               (azimuth_time) float32 60B dask.array<chunksize=(15,), meta=np.ndarray>
#     │   │           model_pg_product_amplitude        (azimuth_time) float32 60B dask.array<chunksize=(15,), meta=np.ndarray>
#     │   │           model_pg_product_phase            (azimuth_time) float32 60B dask.array<chunksize=(15,), meta=np.ndarray>
#     │   │           pg_product_amplitude              (azimuth_time) float32 60B dask.array<chunksize=(15,), meta=np.ndarray>
#     │   │           pg_product_phase                  (azimuth_time) float32 60B dask.array<chunksize=(15,), meta=np.ndarray>
#     │   │           reconstructed_replica_valid_flag  (azimuth_time) bool 15B dask.array<chunksize=(15,), meta=np.ndarray>
#     │   │           relative_pg_product_valid_flag    (azimuth_time) bool 15B dask.array<chunksize=(15,), meta=np.ndarray>
#     │   └── Group: /S01SIWGRD_20240201T164915_0025_A299_750E_065517_VV/conditions/terrain_height
#     │           Dimensions:         (azimuth_time: 5)
#     │           Coordinates:
#     │             * azimuth_time    (azimuth_time) datetime64[ns] 40B 2024-02-01T16:49:05.722...
#     │           Data variables:
#     │               terrain_height  (azimuth_time) float32 20B dask.array<chunksize=(5,), meta=np.ndarray>
#     ├── Group: /S01SIWGRD_20240201T164915_0025_A299_750E_065517_VV/measurements
#     │       Dimensions:       (azimuth_time: 16675, ground_range: 26456)
#     │       Coordinates:
#     │         * azimuth_time  (azimuth_time) datetime64[ns] 133kB 2024-02-01T16:49:15.722...
#     │       Dimensions without coordinates: ground_range
#     │       Data variables:
#     │           grd           (azimuth_time, ground_range) uint16 882MB dask.array<chunksize=(2536, 26456), meta=np.ndarray>
#     └── Group: /S01SIWGRD_20240201T164915_0025_A299_750E_065517_VV/quality
#         ├── Group: /S01SIWGRD_20240201T164915_0025_A299_750E_065517_VV/quality/calibration
#         │       Dimensions:       (azimuth_time: 27, ground_range: 663)
#         │       Coordinates:
#         │         * azimuth_time  (azimuth_time) datetime64[ns] 216B 2024-02-01T16:49:15.7228...
#         │         * ground_range  (ground_range) float32 3kB 0.0 6.67e+06 ... 4.411e+09
#         │           line          (azimuth_time) int32 108B dask.array<chunksize=(27,), meta=np.ndarray>
#         │           pixel         (ground_range) int32 3kB dask.array<chunksize=(663,), meta=np.ndarray>
#         │       Data variables:
#         │           beta_nought   (azimuth_time, ground_range) float32 72kB dask.array<chunksize=(27, 663), meta=np.ndarray>
#         │           dn            (azimuth_time, ground_range) float32 72kB dask.array<chunksize=(27, 663), meta=np.ndarray>
#         │           gamma         (azimuth_time, ground_range) float32 72kB dask.array<chunksize=(27, 663), meta=np.ndarray>
#         │           sigma_nought  (azimuth_time, ground_range) float32 72kB dask.array<chunksize=(27, 663), meta=np.ndarray>
#         └── Group: /S01SIWGRD_20240201T164915_0025_A299_750E_065517_VV/quality/noise
#                 Dimensions:                        (azimuth_time: 797)
#                 Coordinates:
#                   * azimuth_time                   (azimuth_time) datetime64[ns] 6kB 2024-02-...
#                 Data variables:
#                     noise_power_correction_factor  (azimuth_time) float32 3kB dask.array<chunksize=(797,), meta=np.ndarray>
#                     number_of_noise_lines          (azimuth_time) int32 3kB dask.array<chunksize=(797,), meta=np.ndarray>

# %%
ds = dt.S01SIWGRD_20240201T164915_0025_A299_750E_065517_VH.measurements.to_dataset()
ds
# Out:
# <xarray.Dataset> Size: 882MB
# Dimensions:       (azimuth_time: 16675, ground_range: 26456)
# Coordinates:
#   * azimuth_time  (azimuth_time) datetime64[ns] 133kB 2024-02-01T16:49:15.722...
# Dimensions without coordinates: ground_range
# Data variables:
#     grd           (azimuth_time, ground_range) uint16 882MB dask.array<chunksize=(2536, 26456), meta=np.ndarray>
