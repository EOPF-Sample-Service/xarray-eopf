# %%
import xarray as xr

# %%
product_path = (
    "e05ab01a9d56408d82ac32d69a5aae2a:202504-s02msil1c/15/products/cpm_v256/"
    "S2B_MSIL1C_20250415T142749_N0511_R139_T25WEV_20250415T180239.zarr"
)

asset_path = f"{product_path}/measurements/reflectance/r10m"

# %%
ds = xr.open_dataset(f"https://objectstore.eodc.eu:2222/{asset_path}", engine="zarr", chunks={}, consolidated=False)
ds
# Out:
# <xarray.Dataset> Size: 0B
# Dimensions:  ()
# Data variables:
#     *empty*

# %%
ds = xr.open_dataset(f"s3://{asset_path}", engine="eopf-zarr", op_mode="native", chunks={})
ds
# Out:
# <xarray.Dataset> Size: 4GB
# Dimensions:  (y: 10980, x: 10980)
# Coordinates:
#   * x        (x) int64 88kB 499985 499995 500005 500015 ... 609755 609765 609775
#   * y        (y) int64 88kB 8000035 8000025 8000015 ... 7890265 7890255 7890245
# Data variables:
#     b02      (y, x) float64 964MB dask.array<chunksize=(1830, 1830), meta=np.ndarray>
#     b03      (y, x) float64 964MB dask.array<chunksize=(1830, 1830), meta=np.ndarray>
#     b04      (y, x) float64 964MB dask.array<chunksize=(1830, 1830), meta=np.ndarray>
#     b08      (y, x) float64 964MB dask.array<chunksize=(1830, 1830), meta=np.ndarray>
