# %%
import matplotlib.pyplot as plt
import xarray as xr

# %% [markdown]
# ---
# ## Sentinel-3 OLCI L1 EFR

# %%
path = (
    "https://objects.eodc.eu/e05ab01a9d56408d82ac32d69a5aae2a:202508-s03olcefr/19/"
    "products/cpm_v256/S3B_OL_1_EFR____20250819T074058_20250819T074358_"
    "20250819T092155_0179_110_106_3420_ESA_O_NR_004.zarr"
)

# %% [markdown]
# ### Open in native mode

# %%
# %%time
dt = xr.open_datatree(path, engine="eopf-zarr", op_mode="native", chunks={})
dt
# Out:
# CPU times: user 1.03 s, sys: 118 ms, total: 1.15 s
# Wall time: 2.88 s
# <xarray.DataTree>
# Group: /
# │   Attributes: (2)
# ├── Group: /conditions
# │   ├── Group: /conditions/geometry
# │   │       Dimensions:    (tp_rows: 4091, tp_columns: 77)
# │   │       Coordinates:
# │   │           latitude   (tp_rows, tp_columns) float64 3MB dask.array<chunksize=(4091, 77), meta=np.ndarray>
# │   │           longitude  (tp_rows, tp_columns) float64 3MB dask.array<chunksize=(4091, 77), meta=np.ndarray>
# │   │       Dimensions without coordinates: tp_rows, tp_columns
# │   │       Data variables:
# │   │           oaa        (tp_rows, tp_columns) float64 3MB dask.array<chunksize=(4091, 77), meta=np.ndarray>
# │   │           oza        (tp_rows, tp_columns) float64 3MB dask.array<chunksize=(4091, 77), meta=np.ndarray>
# │   │           saa        (tp_rows, tp_columns) float64 3MB dask.array<chunksize=(4091, 77), meta=np.ndarray>
# ...

# %%
ds = dt.measurements.to_dataset()
ds
# Out:
# <xarray.Dataset> Size: 2GB
# Dimensions:        (rows: 4091, columns: 4865)
# Coordinates:
#     latitude       (rows, columns) float64 159MB dask.array<chunksize=(1024, 1024), meta=np.ndarray>
#     longitude      (rows, columns) float64 159MB dask.array<chunksize=(1024, 1024), meta=np.ndarray>
#     time_stamp     (rows) datetime64[ns] 33kB dask.array<chunksize=(1024,), meta=np.ndarray>
# Dimensions without coordinates: rows, columns
# Data variables: (12/21)
#     oa01_radiance  (rows, columns) float32 80MB dask.array<chunksize=(1024, 1024), meta=np.ndarray>
#     oa02_radiance  (rows, columns) float32 80MB dask.array<chunksize=(1024, 1024), meta=np.ndarray>
#     oa03_radiance  (rows, columns) float32 80MB dask.array<chunksize=(1024, 1024), meta=np.ndarray>
#     oa04_radiance  (rows, columns) float32 80MB dask.array<chunksize=(1024, 1024), meta=np.ndarray>
#     oa05_radiance  (rows, columns) float32 80MB dask.array<chunksize=(1024, 1024), meta=np.ndarray>
# ...

# %%
# %%time
ds.oa01_radiance[::4, ::4].plot(robust=True)
# Out:
# CPU times: user 2.45 s, sys: 878 ms, total: 3.33 s
# Wall time: 18.4 s

# %% [markdown]
# ### Open in analysis mode

# %%
# %%time
ds = xr.open_dataset(path, engine="eopf-zarr", chunks={})
ds
# Out:
# CPU times: user 15 s, sys: 3.56 s, total: 18.6 s
# Wall time: 1min 25s
# <xarray.Dataset> Size: 2GB
# Dimensions:        (lon: 5269, lat: 5000)
# Coordinates:
#   * lon            (lon) float64 42kB 18.45 18.46 18.46 ... 34.49 34.5 34.5
#   * lat            (lat) float64 40kB -21.06 -21.06 -21.06 ... -34.53 -34.53
#     spatial_ref    int64 8B ...
# Data variables: (12/21)
#     oa01_radiance  (lat, lon) float32 105MB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     oa02_radiance  (lat, lon) float32 105MB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     oa03_radiance  (lat, lon) float32 105MB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     oa04_radiance  (lat, lon) float32 105MB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     oa05_radiance  (lat, lon) float32 105MB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     oa06_radiance  (lat, lon) float32 105MB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     ...             ...
# ...

# %%
# %%time
ds.oa01_radiance[::5, ::5].plot(robust=True)
# Out:
# CPU times: user 34 s, sys: 10.9 s, total: 44.9 s
# Wall time: 3min 23s

# %% [markdown]
# ---
# ## Sentinel-3 OLCI L1 ERR

# %%
path = (
    "https://objects.eodc.eu/e05ab01a9d56408d82ac32d69a5aae2a:202510-s03olcerr-global/19/products/"
    "cpm_v256/S3A_OL_1_ERR____20251019T145533_20251019T153950_20251019T165332_2657_131_353______PS1_O_NR_004.zarr"
)

# %% [markdown]
# ### Open in native mode

# %%
# %%time
dt = xr.open_datatree(path, engine="eopf-zarr", op_mode="native", chunks={})
dt
# Out:
# CPU times: user 69 ms, sys: 4.53 ms, total: 73.5 ms
# Wall time: 498 ms
# <xarray.DataTree>
# Group: /
# │   Attributes: (2)
# ├── Group: /conditions
# │   ├── Group: /conditions/geometry
# │   │       Dimensions:    (tp_rows: 15098, tp_columns: 77)
# │   │       Coordinates:
# │   │           latitude   (tp_rows, tp_columns) float64 9MB dask.array<chunksize=(7549, 39), meta=np.ndarray>
# │   │           longitude  (tp_rows, tp_columns) float64 9MB dask.array<chunksize=(7549, 39), meta=np.ndarray>
# │   │       Dimensions without coordinates: tp_rows, tp_columns
# │   │       Data variables:
# │   │           oaa        (tp_rows, tp_columns) float64 9MB dask.array<chunksize=(7549, 39), meta=np.ndarray>
# │   │           oza        (tp_rows, tp_columns) float64 9MB dask.array<chunksize=(7549, 39), meta=np.ndarray>
# │   │           saa        (tp_rows, tp_columns) float64 9MB dask.array<chunksize=(7549, 39), meta=np.ndarray>
# ...

# %%
ds = dt.measurements.to_dataset()
ds
# Out:
# <xarray.Dataset> Size: 2GB
# Dimensions:        (rows: 15098, columns: 1217)
# Coordinates:
#     latitude       (rows, columns) float64 147MB dask.array<chunksize=(1024, 1024), meta=np.ndarray>
#     longitude      (rows, columns) float64 147MB dask.array<chunksize=(1024, 1024), meta=np.ndarray>
#     time_stamp     (rows) datetime64[ns] 121kB dask.array<chunksize=(1024,), meta=np.ndarray>
# Dimensions without coordinates: rows, columns
# Data variables: (12/21)
#     oa01_radiance  (rows, columns) float32 73MB dask.array<chunksize=(1024, 1024), meta=np.ndarray>
#     oa02_radiance  (rows, columns) float32 73MB dask.array<chunksize=(1024, 1024), meta=np.ndarray>
#     oa03_radiance  (rows, columns) float32 73MB dask.array<chunksize=(1024, 1024), meta=np.ndarray>
#     oa04_radiance  (rows, columns) float32 73MB dask.array<chunksize=(1024, 1024), meta=np.ndarray>
#     oa05_radiance  (rows, columns) float32 73MB dask.array<chunksize=(1024, 1024), meta=np.ndarray>
# ...

# %%
# %%time
ds.oa01_radiance[::5, :].plot(robust=True, figsize=(2, 10))
# Out:
# CPU times: user 3.13 s, sys: 692 ms, total: 3.82 s
# Wall time: 19.7 s

# %% [markdown]
# ### Open in analysis mode

# %%
# %%time
ds = xr.open_dataset(path, engine="eopf-zarr", chunks={})
ds
# Out:
# CPU times: user 1min 50s, sys: 7.42 s, total: 1min 57s
# Wall time: 3min 20s
# <xarray.Dataset> Size: 13GB
# Dimensions:        (lon: 11065, lat: 14432)
# Coordinates:
#   * lon            (lon) float64 89kB -161.5 -161.5 -161.5 ... -41.75 -41.74
#   * lat            (lat) float64 115kB 72.42 72.41 72.4 ... -83.12 -83.13 -83.14
#     spatial_ref    int64 8B ...
# Data variables: (12/21)
#     oa01_radiance  (lat, lon) float32 639MB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     oa02_radiance  (lat, lon) float32 639MB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     oa03_radiance  (lat, lon) float32 639MB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     oa04_radiance  (lat, lon) float32 639MB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     oa05_radiance  (lat, lon) float32 639MB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     oa06_radiance  (lat, lon) float32 639MB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
# ...

# %%
# %%time
ds.oa01_radiance[::10, ::10].plot(robust=True)
# Out:
# CPU times: user 16min 14s, sys: 54.9 s, total: 17min 9s
# Wall time: 16min 5s

# %% [markdown]
# ---
# ## Sentinel-3 OLCI L2 LFR

# %%
path = (
    "https://objects.eodc.eu/e05ab01a9d56408d82ac32d69a5aae2a:202508-s03olclfr/17/products/cpm_v256/"
    "S3A_OL_2_LFR____20250817T085058_20250817T085358_20250818T125249_0179_129_221_2160_PS1_O_NT_003.zarr"
)

# %% [markdown]
# ### Open in native mode

# %%
# %%time
dt = xr.open_datatree(path, engine="eopf-zarr", chunks={}, op_mode="native")
dt
# Out:
# CPU times: user 51.2 ms, sys: 4.09 ms, total: 55.3 ms
# Wall time: 186 ms
# <xarray.DataTree>
# Group: /
# │   Attributes: (2)
# ├── Group: /conditions
# │   ├── Group: /conditions/geometry
# │   │       Dimensions:    (tp_rows: 4091, tp_columns: 77)
# │   │       Coordinates:
# │   │           latitude   (tp_rows, tp_columns) float64 3MB dask.array<chunksize=(4091, 77), meta=np.ndarray>
# │   │           longitude  (tp_rows, tp_columns) float64 3MB dask.array<chunksize=(4091, 77), meta=np.ndarray>
# │   │       Dimensions without coordinates: tp_rows, tp_columns
# │   │       Data variables:
# │   │           oaa        (tp_rows, tp_columns) float64 3MB dask.array<chunksize=(4091, 77), meta=np.ndarray>
# │   │           oza        (tp_rows, tp_columns) float64 3MB dask.array<chunksize=(4091, 77), meta=np.ndarray>
# │   │           saa        (tp_rows, tp_columns) float64 3MB dask.array<chunksize=(4091, 77), meta=np.ndarray>
# ...

# %%
ds = dt.measurements.to_dataset()
ds
# Out:
# <xarray.Dataset> Size: 716MB
# Dimensions:    (rows: 4091, columns: 4865)
# Coordinates:
#     latitude   (rows, columns) float64 159MB dask.array<chunksize=(1024, 1024), meta=np.ndarray>
#     longitude  (rows, columns) float64 159MB dask.array<chunksize=(1024, 1024), meta=np.ndarray>
# Dimensions without coordinates: rows, columns
# Data variables:
#     gifapar    (rows, columns) float32 80MB dask.array<chunksize=(1024, 1024), meta=np.ndarray>
#     iwv        (rows, columns) float32 80MB dask.array<chunksize=(1024, 1024), meta=np.ndarray>
#     otci       (rows, columns) float32 80MB dask.array<chunksize=(1024, 1024), meta=np.ndarray>
#     rc681      (rows, columns) float32 80MB dask.array<chunksize=(1024, 1024), meta=np.ndarray>
#     rc865      (rows, columns) float32 80MB dask.array<chunksize=(1024, 1024), meta=np.ndarray>

# %%
# %%time
ds.otci[::4, ::4].plot(robust=True)
# Out:
# CPU times: user 2.86 s, sys: 703 ms, total: 3.57 s
# Wall time: 5min 10s

# %% [markdown]
# ### Open in analysis mode

# %%
# %%time
ds = xr.open_dataset(path, engine="eopf-zarr", chunks={})
ds
# Out:
# CPU times: user 1min 3s, sys: 6.8 s, total: 1min 9s
# Wall time: 5min 52s
# <xarray.Dataset> Size: 494MB
# Dimensions:      (lon: 5157, lat: 4790)
# Coordinates:
#   * lon          (lon) float64 41kB 12.51 12.51 12.51 12.52 ... 32.5 32.51 32.51
#   * lat          (lat) float64 38kB 52.45 52.45 52.45 ... 39.55 39.55 39.55
#     spatial_ref  int64 8B ...
# Data variables:
#     gifapar      (lat, lon) float32 99MB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     iwv          (lat, lon) float32 99MB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     otci         (lat, lon) float32 99MB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     rc681        (lat, lon) float32 99MB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     rc865        (lat, lon) float32 99MB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
# Attributes: (11)

# %%
# %%time
ds.otci[::5, ::5].plot(robust=True)
# Out:
# CPU times: user 1min 47s, sys: 9.95 s, total: 1min 57s
# Wall time: 4min 9s

# %% [markdown]
# ----
# ## Sentinel-3 SLSTR L1 RBT

# %%
path = (
    "https://objects.eodc.eu/e05ab01a9d56408d82ac32d69a5aae2a:202510-s03slsrbt-global/19/products/cpm_v256/"
    "S3A_SL_1_RBT____20251019T064521_20251019T064821_20251019T085627_0179_131_348_2700_PS1_O_NR_004.zarr"
)

# %% [markdown]
# ### Open in native mode

# %%
dt = xr.open_datatree(path, engine="eopf-zarr", chunks={}, op_mode="native")
dt
# Out:
# <xarray.DataTree>
# Group: /
# │   Attributes: (2)
# ├── Group: /conditions
# │   ├── Group: /conditions/geometry_tn
# │   │       Dimensions:           (rows: 1200, columns: 130)
# │   │       Coordinates:
# │   │           x                 (rows, columns) float64 1MB dask.array<chunksize=(1200, 130), meta=np.ndarray>
# │   │           y                 (rows, columns) float64 1MB dask.array<chunksize=(1200, 130), meta=np.ndarray>
# │   │       Dimensions without coordinates: rows, columns
# │   │       Data variables:
# │   │           sat_azimuth_tn    (rows, columns) float64 1MB dask.array<chunksize=(1200, 130), meta=np.ndarray>
# │   │           sat_path_tn       (rows, columns) float64 1MB dask.array<chunksize=(1200, 130), meta=np.ndarray>
# │   │           sat_zenith_tn     (rows, columns) float64 1MB dask.array<chunksize=(1200, 130), meta=np.ndarray>
# │   │           solar_azimuth_tn  (rows, columns) float64 1MB dask.array<chunksize=(1200, 130), meta=np.ndarray>
# ...

# %%
ds = dt.measurements.inadir.to_dataset()
ds
# Out:
# <xarray.Dataset> Size: 130MB
# Dimensions:     (rows: 1200, columns: 1500)
# Coordinates:
#     latitude    (rows, columns) float64 14MB dask.array<chunksize=(600, 750), meta=np.ndarray>
#     longitude   (rows, columns) float64 14MB dask.array<chunksize=(600, 750), meta=np.ndarray>
#     x           (rows, columns) float64 14MB dask.array<chunksize=(600, 750), meta=np.ndarray>
#     y           (rows, columns) float64 14MB dask.array<chunksize=(600, 750), meta=np.ndarray>
# Dimensions without coordinates: rows, columns
# Data variables:
#     elevation   (rows, columns) float64 14MB dask.array<chunksize=(1200, 1500), meta=np.ndarray>
#     f2_bt_in    (rows, columns) float64 14MB dask.array<chunksize=(1200, 1500), meta=np.ndarray>
#     s7_bt_in    (rows, columns) float64 14MB dask.array<chunksize=(1200, 1500), meta=np.ndarray>
#     s8_bt_in    (rows, columns) float64 14MB dask.array<chunksize=(1200, 1500), meta=np.ndarray>
# ...

# %%
# %%time
ds.s7_bt_in.plot(robust=True)
# Out:
# CPU times: user 750 ms, sys: 79.6 ms, total: 830 ms
# Wall time: 3.52 s

# %% [markdown]
# ### Open in analysis mode

# %%
# %%time
ds = xr.open_dataset(path, engine="eopf-zarr", chunks={})
ds
# Out:
# CPU times: user 1min 23s, sys: 7.15 s, total: 1min 30s
# Wall time: 2min 7s
# <xarray.Dataset> Size: 2GB
# Dimensions:         (lon: 3326, lat: 2965)
# Coordinates:
#   * lon             (lon) float64 27kB 40.79 40.79 40.79 ... 56.19 56.19 56.19
#   * lat             (lat) float64 24kB 20.93 20.92 20.92 ... 7.622 7.618 7.613
#     spatial_ref     int64 8B ...
# Data variables: (12/29)
#     elevation       (lat, lon) float64 79MB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     s1_radiance_an  (lat, lon) float64 79MB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     s2_radiance_an  (lat, lon) float64 79MB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     s3_radiance_an  (lat, lon) float64 79MB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     s4_radiance_an  (lat, lon) float64 79MB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     s5_radiance_an  (lat, lon) float64 79MB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
# ...

# %%
# %%time
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
ds.s7_bt_in[::2, ::2].plot(ax=ax[0], robust=True)
ds.s7_bt_io[::2, ::2].plot(ax=ax[1], robust=True)
plt.tight_layout()
# Out:
# CPU times: user 14.5 s, sys: 2.18 s, total: 16.7 s
# Wall time: 15.5 s

# %% [markdown]
# ----
# ## Sentinel-3 SLSTR L2 LST

# %%
path = (
    "https://objects.eodc.eu/e05ab01a9d56408d82ac32d69a5aae2a:202510-s03slslst-eu/16/products/cpm_v256/"
    "S3B_SL_2_LST____20251016T215803_20251016T220103_20251017T004323_0179_112_172_0540_ESA_O_NR_004.zarr"
)

# %% [markdown]
# ### Open in native mode

# %%
# %%time
dt = xr.open_datatree(path, engine="eopf-zarr", chunks={}, op_mode="native")
dt
# Out:
# CPU times: user 110 ms, sys: 4.44 ms, total: 115 ms
# Wall time: 662 ms
# <xarray.DataTree>
# Group: /
# │   Attributes: (2)
# ├── Group: /conditions
# │   ├── Group: /conditions/auxiliary
# │   │   │   Dimensions:     (rows: 1200, columns: 1500, nval: 256)
# │   │   │   Dimensions without coordinates: rows, columns, nval
# │   │   │   Data variables:
# │   │   │       biome       (rows, columns) uint8 2MB dask.array<chunksize=(1200, 1500), meta=np.ndarray>
# │   │   │       elevation   (rows, columns) float64 14MB dask.array<chunksize=(1200, 1500), meta=np.ndarray>
# │   │   │       fraction    (rows, columns) float32 7MB dask.array<chunksize=(1200, 1500), meta=np.ndarray>
# │   │   │       ndvi        (rows, columns) float32 7MB dask.array<chunksize=(1200, 1500), meta=np.ndarray>
# │   │   │       tcwv        (rows, columns) float32 7MB dask.array<chunksize=(1200, 1500), meta=np.ndarray>
# │   │   │       validation  (nval) int8 256B dask.array<chunksize=(256,), meta=np.ndarray>
# ...

# %%
# %%time
ds = dt.measurements.to_dataset()
ds
# Out:
# CPU times: user 223 μs, sys: 0 ns, total: 223 μs
# Wall time: 258 μs
# <xarray.Dataset> Size: 65MB
# Dimensions:    (rows: 1200, columns: 1500)
# Coordinates:
#     latitude   (rows, columns) float64 14MB dask.array<chunksize=(600, 750), meta=np.ndarray>
#     longitude  (rows, columns) float64 14MB dask.array<chunksize=(600, 750), meta=np.ndarray>
#     x          (rows, columns) float64 14MB dask.array<chunksize=(600, 750), meta=np.ndarray>
#     y          (rows, columns) float64 14MB dask.array<chunksize=(600, 750), meta=np.ndarray>
# Dimensions without coordinates: rows, columns
# Data variables:
#     lst        (rows, columns) float32 7MB dask.array<chunksize=(1200, 1500), meta=np.ndarray>

# %%
# %%time
ds.lst.plot(robust=True)
# Out:
# CPU times: user 551 ms, sys: 86.1 ms, total: 637 ms
# Wall time: 2.71 s

# %% [markdown]
# ### Open in analysis mode

# %%
# %%time
ds = xr.open_dataset(path, engine="eopf-zarr", chunks={})
ds
# Out:
# CPU times: user 8.16 s, sys: 133 ms, total: 8.3 s
# Wall time: 9.76 s
# <xarray.Dataset> Size: 10MB
# Dimensions:      (lon: 1657, lat: 1473)
# Coordinates:
#   * lon          (lon) float64 13kB -13.52 -13.51 -13.5 ... 5.173 5.184 5.196
#   * lat          (lat) float64 12kB 43.97 43.96 43.95 ... 30.77 30.76 30.75
#     spatial_ref  int64 8B ...
# Data variables:
#     lst          (lat, lon) float32 10MB dask.array<chunksize=(1473, 1657), meta=np.ndarray>
# Attributes: (17)

# %%
# %%time
ds.lst.plot(robust=True)
# Out:
# CPU times: user 1.08 s, sys: 21.5 ms, total: 1.1 s
# Wall time: 1.17 s
