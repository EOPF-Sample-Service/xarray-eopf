# %%
import xarray as xr

# %% [markdown]
# ---
# # Sentinel 2 L1C

# %%
path = (
    "https://objectstore.eodc.eu:2222/e05ab01a9d56408d82ac32d69a5aae2a:sample-data/tutorial_data/"
    "cpm_v253/S2B_MSIL1C_20250113T103309_N0511_R108_T32TLQ_20250113T122458.zarr"
)

# %%
dt = xr.open_datatree(path, engine="eopf-zarr", op_mode="native")
dt
# Out:
# C:\Users\norma\Projects\xarray-eopf\xarray_eopf\backend.py:62: FutureWarning: In a future version of xarray decode_timedelta will default to False rather than None. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   data_tree = xr.open_datatree(
# C:\Users\norma\Projects\xarray-eopf\xarray_eopf\backend.py:62: FutureWarning: In a future version of xarray decode_timedelta will default to False rather than None. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   data_tree = xr.open_datatree(
# <xarray.DataTree>
# Group: /
# │   Attributes:
# │       other_metadata:   {'L0_ancillary_data_quality': 'null', 'L0_ephemeris_dat...
# │       other_metadata4:  {'L0_ancillary_data_quality': 'null', 'L0_ephemeris_dat...
# │       stac_discovery:   {'assets': {'analytic': {'eo:bands': [{'center_waveleng...
# ├── Group: /conditions
# │   ├── Group: /conditions/geometry
# │   │       Dimensions:                        (angle: 2, band: 13, detector: 7, y: 23,
# │   │                                           x: 23)
# │   │       Coordinates:
# │   │         * angle                          (angle) <U7 56B 'zenith' 'azimuth'
# │   │         * band                           (band) <U3 156B 'b01' 'b02' ... 'b11' 'b12'
# │   │         * detector                       (detector) int64 56B 6 7 8 9 10 11 12
# │   │         * x                              (x) int64 184B 300000 305000 ... 410000
# │   │         * y                              (y) int64 184B 5000040 4995040 ... 4890040
# │   │       Data variables:
# │   │           mean_sun_angles                (angle) float64 16B ...
# │   │           mean_viewing_incidence_angles  (band, angle) float64 208B ...
# │   │           sun_angles                     (angle, y, x) float64 8kB ...
# │   │           viewing_incidence_angles       (band, detector, angle, y, x) float64 770kB ...
# │   ├── Group: /conditions/mask
# │   │   ├── Group: /conditions/mask/detector_footprint
# │   │   │   ├── Group: /conditions/mask/detector_footprint/r10m
# │   │   │   │       Dimensions:  (y: 10980, x: 10980)
# │   │   │   │       Coordinates:
# │   │   │   │         * x        (x) int64 88kB 300005 300015 300025 300035 ... 409775 409785 409795
# │   │   │   │         * y        (y) int64 88kB 5000035 5000025 5000015 ... 4890265 4890255 4890245
# │   │   │   │       Data variables:
# │   │   │   │           b02      (y, x) uint8 121MB ...
# │   │   │   │           b03      (y, x) uint8 121MB ...
# │   │   │   │           b04      (y, x) uint8 121MB ...
# │   │   │   │           b08      (y, x) uint8 121MB ...
# │   │   │   ├── Group: /conditions/mask/detector_footprint/r20m
# │   │   │   │       Dimensions:  (y: 5490, x: 5490)
# │   │   │   │       Coordinates:
# │   │   │   │         * x        (x) int64 44kB 300010 300030 300050 300070 ... 409750 409770 409790
# │   │   │   │         * y        (y) int64 44kB 5000030 5000010 4999990 ... 4890290 4890270 4890250
# │   │   │   │       Data variables:
# │   │   │   │           b05      (y, x) uint8 30MB ...
# │   │   │   │           b06      (y, x) uint8 30MB ...
# │   │   │   │           b07      (y, x) uint8 30MB ...
# │   │   │   │           b11      (y, x) uint8 30MB ...
# │   │   │   │           b12      (y, x) uint8 30MB ...
# │   │   │   │           b8a      (y, x) uint8 30MB ...
# │   │   │   └── Group: /conditions/mask/detector_footprint/r60m
# │   │   │           Dimensions:  (y: 1830, x: 1830)
# │   │   │           Coordinates:
# │   │   │             * x        (x) int64 15kB 300030 300090 300150 300210 ... 409650 409710 409770
# │   │   │             * y        (y) int64 15kB 5000010 4999950 4999890 ... 4890390 4890330 4890270
# │   │   │           Data variables:
# │   │   │               b01      (y, x) uint8 3MB ...
# │   │   │               b09      (y, x) uint8 3MB ...
# │   │   │               b10      (y, x) uint8 3MB ...
# │   │   └── Group: /conditions/mask/l1c_classification
# │   │       └── Group: /conditions/mask/l1c_classification/r60m
# │   │               Dimensions:  (y: 1830, x: 1830)
# │   │               Coordinates:
# │   │                 * x        (x) int64 15kB 300030 300090 300150 300210 ... 409650 409710 409770
# │   │                 * y        (y) int64 15kB 5000010 4999950 4999890 ... 4890390 4890330 4890270
# │   │               Data variables:
# │   │                   b00      (y, x) uint8 3MB ...
# │   └── Group: /conditions/meteorology
# │       ├── Group: /conditions/meteorology/cams
# │       │       Dimensions:        (latitude: 9, longitude: 9)
# │       │       Coordinates:
# │       │           isobaricInhPa  float64 8B ...
# │       │         * latitude       (latitude) float64 72B 45.13 45.0 44.88 ... 44.4 44.28 44.16
# │       │         * longitude      (longitude) float64 72B 6.457 6.634 6.811 ... 7.695 7.872
# │       │           number         int64 8B ...
# │       │           step           timedelta64[ns] 8B ...
# │       │           surface        float64 8B ...
# │       │           time           datetime64[ns] 8B ...
# │       │           valid_time     datetime64[ns] 8B ...
# │       │       Data variables:
# │       │           aod1240        (latitude, longitude) float32 324B ...
# │       │           aod469         (latitude, longitude) float32 324B ...
# │       │           aod550         (latitude, longitude) float32 324B ...
# │       │           aod670         (latitude, longitude) float32 324B ...
# │       │           aod865         (latitude, longitude) float32 324B ...
# │       │           bcaod550       (latitude, longitude) float32 324B ...
# │       │           duaod550       (latitude, longitude) float32 324B ...
# │       │           omaod550       (latitude, longitude) float32 324B ...
# │       │           ssaod550       (latitude, longitude) float32 324B ...
# │       │           suaod550       (latitude, longitude) float32 324B ...
# │       │           z              (latitude, longitude) float32 324B ...
# │       │       Attributes:
# │       │           Conventions:             CF-1.7
# │       │           GRIB_centre:             ecmf
# │       │           GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
# │       │           GRIB_edition:            1
# │       │           GRIB_subCentre:          0
# │       │           history:                 2025-02-27T07:57 GRIB to CDM+CF via cfgrib-0.9.1...
# │       │           institution:             European Centre for Medium-Range Weather Forecasts
# │       └── Group: /conditions/meteorology/ecmwf
# │               Dimensions:        (latitude: 9, longitude: 9)
# │               Coordinates:
# │                   isobaricInhPa  float64 8B ...
# │                 * latitude       (latitude) float64 72B 45.13 45.0 44.88 ... 44.4 44.28 44.16
# │                 * longitude      (longitude) float64 72B 6.457 6.634 6.811 ... 7.695 7.872
# │                   number         int64 8B ...
# │                   step           timedelta64[ns] 8B ...
# │                   surface        float64 8B ...
# │                   time           datetime64[ns] 8B ...
# │                   valid_time     datetime64[ns] 8B ...
# │               Data variables:
# │                   msl            (latitude, longitude) float32 324B ...
# │                   r              (latitude, longitude) float32 324B ...
# │                   tco3           (latitude, longitude) float32 324B ...
# │                   tcwv           (latitude, longitude) float32 324B ...
# │                   u10            (latitude, longitude) float32 324B ...
# │                   v10            (latitude, longitude) float32 324B ...
# │               Attributes:
# │                   Conventions:             CF-1.7
# │                   GRIB_centre:             ecmf
# │                   GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
# │                   GRIB_edition:            1
# │                   GRIB_subCentre:          0
# │                   history:                 2025-02-27T07:57 GRIB to CDM+CF via cfgrib-0.9.1...
# │                   institution:             European Centre for Medium-Range Weather Forecasts
# ├── Group: /measurements
# │   └── Group: /measurements/reflectance
# │       ├── Group: /measurements/reflectance/r10m
# │       │       Dimensions:  (y: 10980, x: 10980)
# │       │       Coordinates:
# │       │         * x        (x) int64 88kB 300005 300015 300025 300035 ... 409775 409785 409795
# │       │         * y        (y) int64 88kB 5000035 5000025 5000015 ... 4890265 4890255 4890245
# │       │       Data variables:
# │       │           b02      (y, x) float64 964MB ...
# │       │           b03      (y, x) float64 964MB ...
# │       │           b04      (y, x) float64 964MB ...
# │       │           b08      (y, x) float64 964MB ...
# │       ├── Group: /measurements/reflectance/r20m
# │       │       Dimensions:  (y: 5490, x: 5490)
# │       │       Coordinates:
# │       │         * x        (x) int64 44kB 300010 300030 300050 300070 ... 409750 409770 409790
# │       │         * y        (y) int64 44kB 5000030 5000010 4999990 ... 4890290 4890270 4890250
# │       │       Data variables:
# │       │           b05      (y, x) float64 241MB ...
# │       │           b06      (y, x) float64 241MB ...
# │       │           b07      (y, x) float64 241MB ...
# │       │           b11      (y, x) float64 241MB ...
# │       │           b12      (y, x) float64 241MB ...
# │       │           b8a      (y, x) float64 241MB ...
# │       └── Group: /measurements/reflectance/r60m
# │               Dimensions:  (y: 1830, x: 1830)
# │               Coordinates:
# │                 * x        (x) int64 15kB 300030 300090 300150 300210 ... 409650 409710 409770
# │                 * y        (y) int64 15kB 5000010 4999950 4999890 ... 4890390 4890330 4890270
# │               Data variables:
# │                   b01      (y, x) float64 27MB ...
# │                   b09      (y, x) float64 27MB ...
# │                   b10      (y, x) float64 27MB ...
# └── Group: /quality
#     ├── Group: /quality/l1c_quicklook
#     │   └── Group: /quality/l1c_quicklook/r10m
#     │           Dimensions:  (band: 3, y: 10980, x: 10980)
#     │           Coordinates:
#     │             * band     (band) int64 24B 1 2 3
#     │             * x        (x) int64 88kB 300005 300015 300025 300035 ... 409775 409785 409795
#     │             * y        (y) int64 88kB 5000035 5000025 5000015 ... 4890265 4890255 4890245
#     │           Data variables:
#     │               tci      (band, y, x) uint8 362MB ...
#     └── Group: /quality/mask
#         ├── Group: /quality/mask/r10m
#         │       Dimensions:  (y: 10980, x: 10980)
#         │       Coordinates:
#         │         * x        (x) int64 88kB 300005 300015 300025 300035 ... 409775 409785 409795
#         │         * y        (y) int64 88kB 5000035 5000025 5000015 ... 4890265 4890255 4890245
#         │       Data variables:
#         │           b02      (y, x) uint8 121MB ...
#         │           b03      (y, x) uint8 121MB ...
#         │           b04      (y, x) uint8 121MB ...
#         │           b08      (y, x) uint8 121MB ...
#         ├── Group: /quality/mask/r20m
#         │       Dimensions:  (y: 5490, x: 5490)
#         │       Coordinates:
#         │         * x        (x) int64 44kB 300010 300030 300050 300070 ... 409750 409770 409790
#         │         * y        (y) int64 44kB 5000030 5000010 4999990 ... 4890290 4890270 4890250
#         │       Data variables:
#         │           b05      (y, x) uint8 30MB ...
#         │           b06      (y, x) uint8 30MB ...
#         │           b07      (y, x) uint8 30MB ...
#         │           b11      (y, x) uint8 30MB ...
#         │           b12      (y, x) uint8 30MB ...
#         │           b8a      (y, x) uint8 30MB ...
#         └── Group: /quality/mask/r60m
#                 Dimensions:  (y: 1830, x: 1830)
#                 Coordinates:
#                   * x        (x) int64 15kB 300030 300090 300150 300210 ... 409650 409710 409770
#                   * y        (y) int64 15kB 5000010 4999950 4999890 ... 4890390 4890330 4890270
#                 Data variables:
#                     b01      (y, x) uint8 3MB ...
#                     b09      (y, x) uint8 3MB ...
#                     b10      (y, x) uint8 3MB ...

# %%
ds = dt.measurements.reflectance.r60m
ds
# Out:
# <xarray.DataTree 'r60m'>
# Group: /measurements/reflectance/r60m
#     Dimensions:  (y: 1830, x: 1830)
#     Coordinates:
#       * x        (x) int64 15kB 300030 300090 300150 300210 ... 409650 409710 409770
#       * y        (y) int64 15kB 5000010 4999950 4999890 ... 4890390 4890330 4890270
#     Data variables:
#         b01      (y, x) float64 27MB ...
#         b09      (y, x) float64 27MB ...
#         b10      (y, x) float64 27MB ...

# %%
ds.b01.plot(vmin=0., vmax=0.3)

# %%
ds = xr.open_dataset(path, engine="eopf-zarr", op_mode="native")
ds
# Out:
# C:\Users\norma\Projects\xarray-eopf\xarray_eopf\backend.py:62: FutureWarning: In a future version of xarray decode_timedelta will default to False rather than None. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   data_tree = xr.open_datatree(
# C:\Users\norma\Projects\xarray-eopf\xarray_eopf\backend.py:62: FutureWarning: In a future version of xarray decode_timedelta will default to False rather than None. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   data_tree = xr.open_datatree(
# <xarray.Dataset> Size: 7GB
# Dimensions:                                            (
#                                                         conditions_geometry_angle: 2,
#                                                         conditions_geometry_band: 13,
#                                                         conditions_geometry_y: 23,
#                                                         conditions_geometry_x: 23,
#                                                         conditions_geometry_detector: 7,
#                                                         ...
#                                                         quality_mask_r10m_y: 10980,
#                                                         quality_mask_r10m_x: 10980,
#                                                         quality_mask_r20m_y: 5490,
#                                                         quality_mask_r20m_x: 5490,
#                                                         quality_mask_r60m_y: 1830,
#                                                         quality_mask_r60m_x: 1830)
# Coordinates: (12/44)
#   * conditions_geometry_angle                          (conditions_geometry_angle) <U7 56B ...
#   * conditions_geometry_band                           (conditions_geometry_band) <U3 156B ...
#   * conditions_geometry_detector                       (conditions_geometry_detector) int64 56B ...
#   * conditions_geometry_x                              (conditions_geometry_x) int64 184B ...
#   * conditions_geometry_y                              (conditions_geometry_y) int64 184B ...
#   * conditions_mask_detector_footprint_r10m_x          (conditions_mask_detector_footprint_r10m_x) int64 88kB ...
#     ...                                                 ...
#   * quality_mask_r10m_x                                (quality_mask_r10m_x) int64 88kB ...
#   * quality_mask_r10m_y                                (quality_mask_r10m_y) int64 88kB ...
#   * quality_mask_r20m_x                                (quality_mask_r20m_x) int64 44kB ...
#   * quality_mask_r20m_y                                (quality_mask_r20m_y) int64 44kB ...
#   * quality_mask_r60m_x                                (quality_mask_r60m_x) int64 15kB ...
#   * quality_mask_r60m_y                                (quality_mask_r60m_y) int64 15kB ...
# Data variables: (12/62)
#     conditions_geometry_mean_sun_angles                (conditions_geometry_angle) float64 16B ...
#     conditions_geometry_mean_viewing_incidence_angles  (conditions_geometry_band, conditions_geometry_angle) float64 208B ...
#     conditions_geometry_sun_angles                     (conditions_geometry_angle, conditions_geometry_y, conditions_geometry_x) float64 8kB ...
#     conditions_geometry_viewing_incidence_angles       (conditions_geometry_band, conditions_geometry_detector, conditions_geometry_angle, conditions_geometry_y, conditions_geometry_x) float64 770kB ...
#     conditions_mask_detector_footprint_r10m_b02        (conditions_mask_detector_footprint_r10m_y, conditions_mask_detector_footprint_r10m_x) uint8 121MB ...
#     conditions_mask_detector_footprint_r10m_b03        (conditions_mask_detector_footprint_r10m_y, conditions_mask_detector_footprint_r10m_x) uint8 121MB ...
#     ...                                                 ...
#     quality_mask_r20m_b11                              (quality_mask_r20m_y, quality_mask_r20m_x) uint8 30MB ...
#     quality_mask_r20m_b12                              (quality_mask_r20m_y, quality_mask_r20m_x) uint8 30MB ...
#     quality_mask_r20m_b8a                              (quality_mask_r20m_y, quality_mask_r20m_x) uint8 30MB ...
#     quality_mask_r60m_b01                              (quality_mask_r60m_y, quality_mask_r60m_x) uint8 3MB ...
#     quality_mask_r60m_b09                              (quality_mask_r60m_y, quality_mask_r60m_x) uint8 3MB ...
#     quality_mask_r60m_b10                              (quality_mask_r60m_y, quality_mask_r60m_x) uint8 3MB ...
# Attributes:
#     other_metadata:   {'L0_ancillary_data_quality': 'null', 'L0_ephemeris_dat...
#     other_metadata4:  {'L0_ancillary_data_quality': 'null', 'L0_ephemeris_dat...
#     stac_discovery:   {'assets': {'analytic': {'eo:bands': [{'center_waveleng...

# %%
ds.measurements_r60m_b09.plot(vmin=0., vmax=0.3)

# %% [markdown]
# ---
# # Sentinel 2 L2A

# %%
path = (
    "https://objectstore.eodc.eu:2222/e05ab01a9d56408d82ac32d69a5aae2a:sample-data/tutorial_data/"
    "cpm_v253/S2A_MSIL2A_20240101T102431_N0510_R065_T32TNT_20240101T144052.zarr"
)

# %%
dt = xr.open_datatree(path, engine="eopf-zarr")
dt
# Out:
# /tmp/ipykernel_19672/3667532775.py:1: FutureWarning: In a future version of xarray decode_timedelta will default to False rather than None. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   dt = xr.open_datatree(path, engine="eopf-zarr")
# /tmp/ipykernel_19672/3667532775.py:1: FutureWarning: In a future version of xarray decode_timedelta will default to False rather than None. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   dt = xr.open_datatree(path, engine="eopf-zarr")
# <xarray.DataTree>
# Group: /
# │   Attributes:
# │       other_metadata:  {'AOT_retrieval_model': 'CAMS', 'L0_ancillary_data_quali...
# │       stac_discovery:  {'assets': {'analytic': {'eo:bands': [{'center_wavelengt...
# ├── Group: /conditions
# │   ├── Group: /conditions/geometry
# │   │       Dimensions:                        (angle: 2, band: 13, detector: 7, y: 23,
# │   │                                           x: 23)
# │   │       Coordinates:
# │   │         * angle                          (angle) <U7 56B 'zenith' 'azimuth'
# │   │         * band                           (band) <U3 156B 'b01' 'b02' ... 'b11' 'b12'
# │   │         * detector                       (detector) int64 56B 3 4 5 6 7 8 9
# │   │         * x                              (x) int64 184B 499980 504980 ... 609980
# │   │         * y                              (y) int64 184B 5300040 5295040 ... 5190040
# │   │       Data variables:
# │   │           mean_sun_angles                (angle) float64 16B ...
# │   │           mean_viewing_incidence_angles  (band, angle) float64 208B ...
# │   │           sun_angles                     (angle, y, x) float64 8kB ...
# │   │           viewing_incidence_angles       (band, detector, angle, y, x) float64 770kB ...
# │   ├── Group: /conditions/mask
# │   │   ├── Group: /conditions/mask/detector_footprint
# │   │   │   ├── Group: /conditions/mask/detector_footprint/r10m
# │   │   │   │       Dimensions:  (y: 10980, x: 10980)
# │   │   │   │       Coordinates:
# │   │   │   │         * x        (x) int64 88kB 499985 499995 500005 500015 ... 609755 609765 609775
# │   │   │   │         * y        (y) int64 88kB 5300035 5300025 5300015 ... 5190265 5190255 5190245
# │   │   │   │       Data variables:
# │   │   │   │           b02      (y, x) uint8 121MB ...
# │   │   │   │           b03      (y, x) uint8 121MB ...
# │   │   │   │           b04      (y, x) uint8 121MB ...
# │   │   │   │           b08      (y, x) uint8 121MB ...
# │   │   │   ├── Group: /conditions/mask/detector_footprint/r20m
# │   │   │   │       Dimensions:  (y: 5490, x: 5490)
# │   │   │   │       Coordinates:
# │   │   │   │         * x        (x) int64 44kB 499990 500010 500030 500050 ... 609730 609750 609770
# │   │   │   │         * y        (y) int64 44kB 5300030 5300010 5299990 ... 5190290 5190270 5190250
# │   │   │   │       Data variables:
# │   │   │   │           b05      (y, x) uint8 30MB ...
# │   │   │   │           b06      (y, x) uint8 30MB ...
# │   │   │   │           b07      (y, x) uint8 30MB ...
# │   │   │   │           b11      (y, x) uint8 30MB ...
# │   │   │   │           b12      (y, x) uint8 30MB ...
# │   │   │   │           b8a      (y, x) uint8 30MB ...
# │   │   │   └── Group: /conditions/mask/detector_footprint/r60m
# │   │   │           Dimensions:  (y: 1830, x: 1830)
# │   │   │           Coordinates:
# │   │   │             * x        (x) int64 15kB 500010 500070 500130 500190 ... 609630 609690 609750
# │   │   │             * y        (y) int64 15kB 5300010 5299950 5299890 ... 5190390 5190330 5190270
# │   │   │           Data variables:
# │   │   │               b01      (y, x) uint8 3MB ...
# │   │   │               b09      (y, x) uint8 3MB ...
# │   │   │               b10      (y, x) uint8 3MB ...
# │   │   ├── Group: /conditions/mask/l1c_classification
# │   │   │   └── Group: /conditions/mask/l1c_classification/r60m
# │   │   │           Dimensions:  (y: 1830, x: 1830)
# │   │   │           Coordinates:
# │   │   │             * x        (x) int64 15kB 500010 500070 500130 500190 ... 609630 609690 609750
# │   │   │             * y        (y) int64 15kB 5300010 5299950 5299890 ... 5190390 5190330 5190270
# │   │   │           Data variables:
# │   │   │               b00      (y, x) uint8 3MB ...
# │   │   └── Group: /conditions/mask/l2a_classification
# │   │       ├── Group: /conditions/mask/l2a_classification/r20m
# │   │       │       Dimensions:  (y: 5490, x: 5490)
# │   │       │       Coordinates:
# │   │       │         * x        (x) int64 44kB 499990 500010 500030 500050 ... 609730 609750 609770
# │   │       │         * y        (y) int64 44kB 5300030 5300010 5299990 ... 5190290 5190270 5190250
# │   │       │       Data variables:
# │   │       │           scl      (y, x) uint8 30MB ...
# │   │       └── Group: /conditions/mask/l2a_classification/r60m
# │   │               Dimensions:  (y: 1830, x: 1830)
# │   │               Coordinates:
# │   │                 * x        (x) int64 15kB 500010 500070 500130 500190 ... 609630 609690 609750
# │   │                 * y        (y) int64 15kB 5300010 5299950 5299890 ... 5190390 5190330 5190270
# │   │               Data variables:
# │   │                   scl      (y, x) uint8 3MB ...
# │   └── Group: /conditions/meteorology
# │       ├── Group: /conditions/meteorology/cams
# │       │       Dimensions:        (latitude: 9, longitude: 9)
# │       │       Coordinates:
# │       │           isobaricInhPa  float64 8B ...
# │       │         * latitude       (latitude) float64 72B 47.85 47.73 47.6 ... 47.1 46.98 46.86
# │       │         * longitude      (longitude) float64 72B 9.0 9.18 9.36 ... 10.08 10.26 10.44
# │       │           number         int64 8B ...
# │       │           step           timedelta64[ns] 8B ...
# │       │           surface        float64 8B ...
# │       │           time           datetime64[ns] 8B ...
# │       │           valid_time     datetime64[ns] 8B ...
# │       │       Data variables:
# │       │           aod1240        (latitude, longitude) float32 324B ...
# │       │           aod469         (latitude, longitude) float32 324B ...
# │       │           aod550         (latitude, longitude) float32 324B ...
# │       │           aod670         (latitude, longitude) float32 324B ...
# │       │           aod865         (latitude, longitude) float32 324B ...
# │       │           bcaod550       (latitude, longitude) float32 324B ...
# │       │           duaod550       (latitude, longitude) float32 324B ...
# │       │           omaod550       (latitude, longitude) float32 324B ...
# │       │           ssaod550       (latitude, longitude) float32 324B ...
# │       │           suaod550       (latitude, longitude) float32 324B ...
# │       │           z              (latitude, longitude) float32 324B ...
# │       │       Attributes:
# │       │           Conventions:             CF-1.7
# │       │           GRIB_centre:             ecmf
# │       │           GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
# │       │           GRIB_edition:            1
# │       │           GRIB_subCentre:          0
# │       │           history:                 2025-02-27T09:49 GRIB to CDM+CF via cfgrib-0.9.1...
# │       │           institution:             European Centre for Medium-Range Weather Forecasts
# │       └── Group: /conditions/meteorology/ecmwf
# │               Dimensions:        (latitude: 9, longitude: 9)
# │               Coordinates:
# │                   isobaricInhPa  float64 8B ...
# │                 * latitude       (latitude) float64 72B 47.85 47.73 47.6 ... 47.1 46.98 46.86
# │                 * longitude      (longitude) float64 72B 9.0 9.18 9.36 ... 10.08 10.26 10.44
# │                   number         int64 8B ...
# │                   step           timedelta64[ns] 8B ...
# │                   surface        float64 8B ...
# │                   time           datetime64[ns] 8B ...
# │                   valid_time     datetime64[ns] 8B ...
# │               Data variables:
# │                   msl            (latitude, longitude) float32 324B ...
# │                   r              (latitude, longitude) float32 324B ...
# │                   tco3           (latitude, longitude) float32 324B ...
# │                   tcwv           (latitude, longitude) float32 324B ...
# │                   u10            (latitude, longitude) float32 324B ...
# │                   v10            (latitude, longitude) float32 324B ...
# │               Attributes:
# │                   Conventions:             CF-1.7
# │                   GRIB_centre:             ecmf
# │                   GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
# │                   GRIB_edition:            1
# │                   GRIB_subCentre:          0
# │                   history:                 2025-02-27T09:49 GRIB to CDM+CF via cfgrib-0.9.1...
# │                   institution:             European Centre for Medium-Range Weather Forecasts
# ├── Group: /measurements
# │   └── Group: /measurements/reflectance
# │       ├── Group: /measurements/reflectance/r10m
# │       │       Dimensions:  (y: 10980, x: 10980)
# │       │       Coordinates:
# │       │         * x        (x) int64 88kB 499985 499995 500005 500015 ... 609755 609765 609775
# │       │         * y        (y) int64 88kB 5300035 5300025 5300015 ... 5190265 5190255 5190245
# │       │       Data variables:
# │       │           b02      (y, x) float64 964MB ...
# │       │           b03      (y, x) float64 964MB ...
# │       │           b04      (y, x) float64 964MB ...
# │       │           b08      (y, x) float64 964MB ...
# │       ├── Group: /measurements/reflectance/r20m
# │       │       Dimensions:  (y: 5490, x: 5490)
# │       │       Coordinates:
# │       │         * x        (x) int64 44kB 499990 500010 500030 500050 ... 609730 609750 609770
# │       │         * y        (y) int64 44kB 5300030 5300010 5299990 ... 5190290 5190270 5190250
# │       │       Data variables:
# │       │           b01      (y, x) float64 241MB ...
# │       │           b02      (y, x) float64 241MB ...
# │       │           b03      (y, x) float64 241MB ...
# │       │           b04      (y, x) float64 241MB ...
# │       │           b05      (y, x) float64 241MB ...
# │       │           b06      (y, x) float64 241MB ...
# │       │           b07      (y, x) float64 241MB ...
# │       │           b11      (y, x) float64 241MB ...
# │       │           b12      (y, x) float64 241MB ...
# │       │           b8a      (y, x) float64 241MB ...
# │       └── Group: /measurements/reflectance/r60m
# │               Dimensions:  (y: 1830, x: 1830)
# │               Coordinates:
# │                 * x        (x) int64 15kB 500010 500070 500130 500190 ... 609630 609690 609750
# │                 * y        (y) int64 15kB 5300010 5299950 5299890 ... 5190390 5190330 5190270
# │               Data variables:
# │                   b01      (y, x) float64 27MB ...
# │                   b02      (y, x) float64 27MB ...
# │                   b03      (y, x) float64 27MB ...
# │                   b04      (y, x) float64 27MB ...
# │                   b05      (y, x) float64 27MB ...
# │                   b06      (y, x) float64 27MB ...
# │                   b07      (y, x) float64 27MB ...
# │                   b09      (y, x) float64 27MB ...
# │                   b11      (y, x) float64 27MB ...
# │                   b12      (y, x) float64 27MB ...
# │                   b8a      (y, x) float64 27MB ...
# └── Group: /quality
#     ├── Group: /quality/atmosphere
#     │   ├── Group: /quality/atmosphere/r10m
#     │   │       Dimensions:  (y: 10980, x: 10980)
#     │   │       Coordinates:
#     │   │         * x        (x) int64 88kB 499985 499995 500005 500015 ... 609755 609765 609775
#     │   │         * y        (y) int64 88kB 5300035 5300025 5300015 ... 5190265 5190255 5190245
#     │   │       Data variables:
#     │   │           aot      (y, x) uint16 241MB ...
#     │   │           wvp      (y, x) uint16 241MB ...
#     │   ├── Group: /quality/atmosphere/r20m
#     │   │       Dimensions:  (y: 5490, x: 5490)
#     │   │       Coordinates:
#     │   │         * x        (x) int64 44kB 499990 500010 500030 500050 ... 609730 609750 609770
#     │   │         * y        (y) int64 44kB 5300030 5300010 5299990 ... 5190290 5190270 5190250
#     │   │       Data variables:
#     │   │           aot      (y, x) uint16 60MB ...
#     │   │           wvp      (y, x) uint16 60MB ...
#     │   └── Group: /quality/atmosphere/r60m
#     │           Dimensions:  (y: 1830, x: 1830)
#     │           Coordinates:
#     │             * x        (x) int64 15kB 500010 500070 500130 500190 ... 609630 609690 609750
#     │             * y        (y) int64 15kB 5300010 5299950 5299890 ... 5190390 5190330 5190270
#     │           Data variables:
#     │               aot      (y, x) uint16 7MB ...
#     │               wvp      (y, x) uint16 7MB ...
#     ├── Group: /quality/l2a_quicklook
#     │   ├── Group: /quality/l2a_quicklook/r10m
#     │   │       Dimensions:  (band: 3, y: 10980, x: 10980)
#     │   │       Coordinates:
#     │   │         * band     (band) int64 24B 1 2 3
#     │   │         * x        (x) int64 88kB 499985 499995 500005 500015 ... 609755 609765 609775
#     │   │         * y        (y) int64 88kB 5300035 5300025 5300015 ... 5190265 5190255 5190245
#     │   │       Data variables:
#     │   │           tci      (band, y, x) uint8 362MB ...
#     │   ├── Group: /quality/l2a_quicklook/r20m
#     │   │       Dimensions:  (band: 3, y: 5490, x: 5490)
#     │   │       Coordinates:
#     │   │         * band     (band) int64 24B 1 2 3
#     │   │         * x        (x) int64 44kB 499990 500010 500030 500050 ... 609730 609750 609770
#     │   │         * y        (y) int64 44kB 5300030 5300010 5299990 ... 5190290 5190270 5190250
#     │   │       Data variables:
#     │   │           tci      (band, y, x) uint8 90MB ...
#     │   └── Group: /quality/l2a_quicklook/r60m
#     │           Dimensions:  (band: 3, y: 1830, x: 1830)
#     │           Coordinates:
#     │             * band     (band) int64 24B 1 2 3
#     │             * x        (x) int64 15kB 500010 500070 500130 500190 ... 609630 609690 609750
#     │             * y        (y) int64 15kB 5300010 5299950 5299890 ... 5190390 5190330 5190270
#     │           Data variables:
#     │               tci      (band, y, x) uint8 10MB ...
#     ├── Group: /quality/mask
#     │   ├── Group: /quality/mask/r10m
#     │   │       Dimensions:  (y: 10980, x: 10980)
#     │   │       Coordinates:
#     │   │         * x        (x) int64 88kB 499985 499995 500005 500015 ... 609755 609765 609775
#     │   │         * y        (y) int64 88kB 5300035 5300025 5300015 ... 5190265 5190255 5190245
#     │   │       Data variables:
#     │   │           b02      (y, x) uint8 121MB ...
#     │   │           b03      (y, x) uint8 121MB ...
#     │   │           b04      (y, x) uint8 121MB ...
#     │   │           b08      (y, x) uint8 121MB ...
#     │   ├── Group: /quality/mask/r20m
#     │   │       Dimensions:  (y: 5490, x: 5490)
#     │   │       Coordinates:
#     │   │         * x        (x) int64 44kB 499990 500010 500030 500050 ... 609730 609750 609770
#     │   │         * y        (y) int64 44kB 5300030 5300010 5299990 ... 5190290 5190270 5190250
#     │   │       Data variables:
#     │   │           b05      (y, x) uint8 30MB ...
#     │   │           b06      (y, x) uint8 30MB ...
#     │   │           b07      (y, x) uint8 30MB ...
#     │   │           b11      (y, x) uint8 30MB ...
#     │   │           b12      (y, x) uint8 30MB ...
#     │   │           b8a      (y, x) uint8 30MB ...
#     │   └── Group: /quality/mask/r60m
#     │           Dimensions:  (y: 1830, x: 1830)
#     │           Coordinates:
#     │             * x        (x) int64 15kB 500010 500070 500130 500190 ... 609630 609690 609750
#     │             * y        (y) int64 15kB 5300010 5299950 5299890 ... 5190390 5190330 5190270
#     │           Data variables:
#     │               b01      (y, x) uint8 3MB ...
#     │               b09      (y, x) uint8 3MB ...
#     │               b10      (y, x) uint8 3MB ...
#     └── Group: /quality/probability
#         └── Group: /quality/probability/r20m
#                 Dimensions:  (y: 5490, x: 5490)
#                 Coordinates:
#                     band     int64 8B ...
#                   * x        (x) int64 44kB 499990 500010 500030 500050 ... 609730 609750 609770
#                   * y        (y) int64 44kB 5300030 5300010 5299990 ... 5190290 5190270 5190250
#                 Data variables:
#                     cld      (y, x) uint8 30MB ...
#                     snw      (y, x) uint8 30MB ...

# %%
ds = dt.measurements.reflectance.r60m
ds
# Out:
# <xarray.DataTree 'r60m'>
# Group: /measurements/reflectance/r60m
#     Dimensions:  (y: 1830, x: 1830)
#     Coordinates:
#       * x        (x) int64 15kB 500010 500070 500130 500190 ... 609630 609690 609750
#       * y        (y) int64 15kB 5300010 5299950 5299890 ... 5190390 5190330 5190270
#     Data variables:
#         b01      (y, x) float64 27MB ...
#         b02      (y, x) float64 27MB ...
#         b03      (y, x) float64 27MB ...
#         b04      (y, x) float64 27MB ...
#         b05      (y, x) float64 27MB ...
#         b06      (y, x) float64 27MB ...
#         b07      (y, x) float64 27MB ...
#         b09      (y, x) float64 27MB ...
#         b11      (y, x) float64 27MB ...
#         b12      (y, x) float64 27MB ...
#         b8a      (y, x) float64 27MB ...

# %%
ds.b04.plot(vmin=0., vmax=0.3)
