# %%
import xarray as xr

# %% [markdown]
# ---
# # Sentinel 2 L1C

# %%
path = (
    "https://objectstore.eodc.eu:2222/e05ab01a9d56408d82ac32d69a5aae2a:sample-data/"
    "eopf-sample-output/S2A_MSIL1C_20240101T020101_N0510_R060_T52SGB_20240101T031507.zarr"
)

# %%
dt = xr.open_datatree(path, engine="zarr")
dt
# Out:
# <xarray.DataTree>
# Group: /
# │   Attributes:
# │       other_metadata:   {'L0_ancillary_data_quality': '3', 'L0_ephemeris_data_q...
# │       other_metadata4:  {'L0_ancillary_data_quality': 'null', 'L0_ephemeris_dat...
# │       stac_discovery:   {'assets': {}, 'bbox': [132.3300970771766, 32.406061018...
# ├── Group: /conditions
# │   ├── Group: /conditions/geometry
# │   │       Dimensions:                        (angle: 2, band: 13, detector: 6, y: 23,
# │   │                                           x: 23)
# │   │       Coordinates:
# │   │         * angle                          (angle) <U7 56B 'zenith' 'azimuth'
# │   │         * band                           (band) <U3 156B 'b01' 'b02' ... 'b11' 'b12'
# │   │         * detector                       (detector) int64 48B 7 8 9 10 11 12
# │   │         * x                              (x) int64 184B 699960 704960 ... 809960
# │   │         * y                              (y) int64 184B 3700020 3695020 ... 3590020
# ...

# %% [markdown]
# ---
# # Sentinel 2 L2A

# %%
path = (
    "https://objectstore.eodc.eu:2222/e05ab01a9d56408d82ac32d69a5aae2a:sample-data"
    "/eopf-sample-output/S2A_MSIL2A_20240101T102431_N0510_R065_T32UQV_20240101T120753.zarr"
)

# %%
dt = xr.open_datatree(path, engine="zarr")
dt
# Out:
# <xarray.DataTree>
# Group: /
# │   Attributes:
# │       other_metadata:  {'L0_ancillary_data_quality': '4', 'L0_ephemeris_data_qu...
# │       stac_discovery:  {'assets': {}, 'bbox': [13.002132905916916, 48.608156227...
# ├── Group: /conditions
# │   ├── Group: /conditions/geometry
# │   │       Dimensions:                        (angle: 2, band: 13, detector: 4, y: 23,
# │   │                                           x: 23)
# │   │       Coordinates:
# │   │         * angle                          (angle) <U7 56B 'zenith' 'azimuth'
# │   │         * band                           (band) <U3 156B 'b01' 'b02' ... 'b11' 'b12'
# │   │         * detector                       (detector) int64 32B 9 10 11 12
# │   │         * x                              (x) int64 184B 699960 704960 ... 809960
# │   │         * y                              (y) int64 184B 5500020 5495020 ... 5390020
# │   │       Data variables:
# ...
